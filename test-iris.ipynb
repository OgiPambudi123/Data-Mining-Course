# %%
import pandas as pd

# %%
pd.read_csv('iris.csv')
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.to_csv ('iris_new.csv', index=False)

# %%
df.iloc[1:4]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %%
df.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal_Length, Length: 150, dtype: float64

# %%
df.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class'], dtype='object')

# %%
def halo_ogi():
    print ('Selamat Siang, semoga harimu menyenangkan!!!')

# %%
halo_ogi()
# Out:
# Selamat Siang, semoga harimu menyenangkan!!!

# %%
for index, row in df.iterrows():
    print(index,row['Class'])
# Out:
# 0 Setosa
# 1 Setosa
# 2 Setosa
# 3 Setosa
# 4 Setosa
# 5 Setosa
# 6 Setosa
# 7 Setosa
# 8 Setosa
# 9 Setosa
# 10 Setosa
# 11 Setosa
# 12 Setosa
# 13 Setosa
# 14 Setosa
# 15 Setosa
# 16 Setosa
# 17 Setosa
# 18 Setosa
# 19 Setosa
# 20 Setosa
# 21 Setosa
# 22 Setosa
# 23 Setosa
# 24 Setosa
# 25 Setosa
# 26 Setosa
# 27 Setosa
# 28 Setosa
# 29 Setosa
# 30 Setosa
# 31 Setosa
# 32 Setosa
# 33 Setosa
# 34 Setosa
# 35 Setosa
# 36 Setosa
# 37 Setosa
# 38 Setosa
# 39 Setosa
# 40 Setosa
# 41 Setosa
# 42 Setosa
# 43 Setosa
# 44 Setosa
# 45 Setosa
# 46 Setosa
# 47 Setosa
# 48 Setosa
# 49 Setosa
# 50 Versicolor
# 51 Versicolor
# 52 Versicolor
# 53 Versicolor
# 54 Versicolor
# 55 Versicolor
# 56 Versicolor
# 57 Versicolor
# 58 Versicolor
# 59 Versicolor
# 60 Versicolor
# 61 Versicolor
# 62 Versicolor
# 63 Versicolor
# 64 Versicolor
# 65 Versicolor
# 66 Versicolor
# 67 Versicolor
# 68 Versicolor
# 69 Versicolor
# 70 Versicolor
# 71 Versicolor
# 72 Versicolor
# 73 Versicolor
# 74 Versicolor
# ...

# %%
df.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.sort_values(['Sepal_Length', 'Sepal_Width'], ascending=True)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class
# 13            4.3          3.0           1.1          0.1     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 38            4.4          3.0           1.3          0.2     Setosa
# 42            4.4          3.2           1.3          0.2     Setosa
# 41            4.5          2.3           1.3          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 118           7.7          2.6           6.9          2.3  Virginica
# 122           7.7          2.8           6.7          2.0  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# 117           7.7          3.8           6.7          2.2  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica
#
# [150 rows x 5 columns]

# %%
df['SepalNew_Length'] = df['Petal_Length']

# %%
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalNew_Length
# 0                1.4
# 1                1.4
# 2                1.3
# 3                1.5
# 4                1.4
# ...

# %%
df = df.drop(columns=['SepalNew_Length'])

# %%
df['jumlah']=df.iloc[:,1:3].sum(axis=1)

# %%
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class  jumlah
# 0             5.1          3.5           1.4          0.2     Setosa     4.9
# 1             4.9          3.0           1.4          0.2     Setosa     4.4
# 2             4.7          3.2           1.3          0.2     Setosa     4.5
# 3             4.6          3.1           1.5          0.2     Setosa     4.6
# 4             5.0          3.6           1.4          0.2     Setosa     5.0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  Virginica     8.2
# 146           6.3          2.5           5.0          1.9  Virginica     7.5
# 147           6.5          3.0           5.2          2.0  Virginica     8.2
# 148           6.2          3.4           5.4          2.3  Virginica     8.8
# 149           5.9          3.0           5.1          1.8  Virginica     8.1
#
# [150 rows x 6 columns]

# %%
#Penanganan Missing Value
#mengganti missing value dengan nilai hasil interpolasi

df.interpolate(method='linear',limit_direction ='forward')
# Out:
# /tmp/ipykernel_6712/3913012928.py:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear',limit_direction ='forward')
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class  jumlah
# 0             5.1          3.5           1.4          0.2     Setosa     4.9
# 1             4.9          3.0           1.4          0.2     Setosa     4.4
# 2             4.7          3.2           1.3          0.2     Setosa     4.5
# 3             4.6          3.1           1.5          0.2     Setosa     4.6
# 4             5.0          3.6           1.4          0.2     Setosa     5.0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  Virginica     8.2
# 146           6.3          2.5           5.0          1.9  Virginica     7.5
# ...

# %%
#menghapus data baris jika ditemukan minimal 1 missing values

df.dropna()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class  jumlah
# 0             5.1          3.5           1.4          0.2     Setosa     4.9
# 1             4.9          3.0           1.4          0.2     Setosa     4.4
# 2             4.7          3.2           1.3          0.2     Setosa     4.5
# 3             4.6          3.1           1.5          0.2     Setosa     4.6
# 4             5.0          3.6           1.4          0.2     Setosa     5.0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  Virginica     8.2
# 146           6.3          2.5           5.0          1.9  Virginica     7.5
# 147           6.5          3.0           5.2          2.0  Virginica     8.2
# 148           6.2          3.4           5.4          2.3  Virginica     8.8
# 149           5.9          3.0           5.1          1.8  Virginica     8.1
#
# [150 rows x 6 columns]

# %%
#mengahpus baris data jika baris data berisi missing value semua

df.dropna(how='all')
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class  jumlah
# 0             5.1          3.5           1.4          0.2     Setosa     4.9
# 1             4.9          3.0           1.4          0.2     Setosa     4.4
# 2             4.7          3.2           1.3          0.2     Setosa     4.5
# 3             4.6          3.1           1.5          0.2     Setosa     4.6
# 4             5.0          3.6           1.4          0.2     Setosa     5.0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  Virginica     8.2
# 146           6.3          2.5           5.0          1.9  Virginica     7.5
# 147           6.5          3.0           5.2          2.0  Virginica     8.2
# 148           6.2          3.4           5.4          2.3  Virginica     8.8
# 149           5.9          3.0           5.1          1.8  Virginica     8.1
#
# [150 rows x 6 columns]
